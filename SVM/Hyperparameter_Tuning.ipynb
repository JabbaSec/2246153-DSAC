# %%
import joblib
import pandas as pd
import warnings
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.svm import SVC

warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %% [markdown]
# # Load Data

# %%
tr_features = pd.read_csv('./DATASET/train_features.csv')
tr_labels = pd.read_csv('./DATASET/train_labels.csv')

# %% [markdown]
# # Find best hyperparameters

# %%
def print_results(results):
    print('Best Parameters: {}\n'.format(results.best_params_))
    means = results.cv_results_['mean_test_score']
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print('{} (+/-{}) for {}'.format(round(mean, 3), round(std * 2, 3), params))

# %%
svc = SVC()

parameters = {
    'kernel': ['linear', 'rbf', 'poly'],
    'C': [0.1, 1, 10],
    'gamma': ['scale', 'auto'],
    'class_weight': ['balanced']
}

cv = StratifiedKFold(n_splits=5)
grid_search  = GridSearchCV(svc, parameters, cv=cv, return_train_score=True, n_jobs=1, verbose=10)

grid_search.fit(tr_features, tr_labels.values.ravel())

print_results(grid_search)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [CV 1/5; 1/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 1/5; 1/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.959) total time=  24.6s
# [CV 2/5; 1/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 2/5; 1/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.961, test=0.961) total time=  26.0s
# [CV 3/5; 1/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 3/5; 1/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.960) total time=  24.8s
# [CV 4/5; 1/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 4/5; 1/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.959) total time=  24.2s
# [CV 5/5; 1/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 5/5; 1/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.957) total time=  23.1s
# [CV 1/5; 2/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 1/5; 2/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.986, test=0.986) total time=  22.0s
# [CV 2/5; 2/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 2/5; 2/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.987, test=0.987) total time=  22.4s
# [CV 3/5; 2/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 3/5; 2/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.986, test=0.986) total time=  21.7s
# [CV 4/5; 2/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 4/5; 2/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.986, test=0.986) total time=  23.5s
# [CV 5/5; 2/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 5/5; 2/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.987, test=0.985) total time=  23.3s
# [CV 1/5; 3/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 1/5; 3/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.976, test=0.973) total time=  19.2s
# [CV 2/5; 3/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 2/5; 3/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.975, test=0.978) total time=  19.7s
# [CV 3/5; 3/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 3/5; 3/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.976, test=0.976) total time=  19.5s
# [CV 4/5; 3/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 4/5; 3/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.977, test=0.976) total time=  19.1s
# [CV 5/5; 3/18] START C=0.1, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 5/5; 3/18] END C=0.1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.977, test=0.974) total time=  19.1s
# [CV 1/5; 4/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 1/5; 4/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.959) total time=  23.8s
# [CV 2/5; 4/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 2/5; 4/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.961, test=0.961) total time=  23.6s
# [CV 3/5; 4/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 3/5; 4/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.960) total time=  24.8s
# [CV 4/5; 4/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 4/5; 4/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.959) total time=  24.2s
# [CV 5/5; 4/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 5/5; 4/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.957) total time=  23.1s
# [CV 1/5; 5/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 1/5; 5/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.986, test=0.986) total time=  23.2s
# [CV 2/5; 5/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 2/5; 5/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.987, test=0.987) total time=  22.9s
# [CV 3/5; 5/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 3/5; 5/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.986, test=0.986) total time=  22.1s
# [CV 4/5; 5/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 4/5; 5/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.986, test=0.986) total time=  22.2s
# [CV 5/5; 5/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 5/5; 5/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.986, test=0.985) total time=  22.5s
# [CV 1/5; 6/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 1/5; 6/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.976, test=0.973) total time=  19.5s
# [CV 2/5; 6/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 2/5; 6/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.975, test=0.978) total time=  19.9s
# [CV 3/5; 6/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 3/5; 6/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.975, test=0.975) total time=  19.6s
# [CV 4/5; 6/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 4/5; 6/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.976, test=0.975) total time=  19.4s
# [CV 5/5; 6/18] START C=0.1, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 5/5; 6/18] END C=0.1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.976, test=0.973) total time=  19.3s
# [CV 1/5; 7/18] START C=1, class_weight=balanced, gamma=scale, kernel=linear.....
# [CV 1/5; 7/18] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.960, test=0.959) total time=  44.0s
# [CV 2/5; 7/18] START C=1, class_weight=balanced, gamma=scale, kernel=linear.....
# [CV 2/5; 7/18] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.964, test=0.965) total time=  45.1s
# [CV 3/5; 7/18] START C=1, class_weight=balanced, gamma=scale, kernel=linear.....
# [CV 3/5; 7/18] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.961) total time=  44.1s
# [CV 4/5; 7/18] START C=1, class_weight=balanced, gamma=scale, kernel=linear.....
# [CV 4/5; 7/18] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.962, test=0.961) total time=  40.3s
# [CV 5/5; 7/18] START C=1, class_weight=balanced, gamma=scale, kernel=linear.....
# [CV 5/5; 7/18] END C=1, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.957) total time=  41.2s
# [CV 1/5; 8/18] START C=1, class_weight=balanced, gamma=scale, kernel=rbf........
# [CV 1/5; 8/18] END C=1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.992, test=0.991) total time=  12.4s
# [CV 2/5; 8/18] START C=1, class_weight=balanced, gamma=scale, kernel=rbf........
# [CV 2/5; 8/18] END C=1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.992, test=0.991) total time=  12.9s
# [CV 3/5; 8/18] START C=1, class_weight=balanced, gamma=scale, kernel=rbf........
# [CV 3/5; 8/18] END C=1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.992, test=0.991) total time=  12.8s
# [CV 4/5; 8/18] START C=1, class_weight=balanced, gamma=scale, kernel=rbf........
# [CV 4/5; 8/18] END C=1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.992, test=0.992) total time=  12.5s
# [CV 5/5; 8/18] START C=1, class_weight=balanced, gamma=scale, kernel=rbf........
# [CV 5/5; 8/18] END C=1, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.992, test=0.991) total time=  12.2s
# [CV 1/5; 9/18] START C=1, class_weight=balanced, gamma=scale, kernel=poly.......
# [CV 1/5; 9/18] END C=1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.987, test=0.986) total time=  12.1s
# [CV 2/5; 9/18] START C=1, class_weight=balanced, gamma=scale, kernel=poly.......
# [CV 2/5; 9/18] END C=1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.988, test=0.986) total time=  12.3s
# [CV 3/5; 9/18] START C=1, class_weight=balanced, gamma=scale, kernel=poly.......
# [CV 3/5; 9/18] END C=1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.989, test=0.988) total time=  12.1s
# [CV 4/5; 9/18] START C=1, class_weight=balanced, gamma=scale, kernel=poly.......
# [CV 4/5; 9/18] END C=1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.990, test=0.990) total time=  11.6s
# [CV 5/5; 9/18] START C=1, class_weight=balanced, gamma=scale, kernel=poly.......
# [CV 5/5; 9/18] END C=1, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.989, test=0.987) total time=  11.9s
# [CV 1/5; 10/18] START C=1, class_weight=balanced, gamma=auto, kernel=linear.....
# [CV 1/5; 10/18] END C=1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.960, test=0.959) total time=  43.6s
# [CV 2/5; 10/18] START C=1, class_weight=balanced, gamma=auto, kernel=linear.....
# [CV 2/5; 10/18] END C=1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.964, test=0.965) total time=  44.6s
# [CV 3/5; 10/18] START C=1, class_weight=balanced, gamma=auto, kernel=linear.....
# [CV 3/5; 10/18] END C=1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.961) total time=  44.0s
# [CV 4/5; 10/18] START C=1, class_weight=balanced, gamma=auto, kernel=linear.....
# [CV 4/5; 10/18] END C=1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.962, test=0.961) total time=  40.4s
# [CV 5/5; 10/18] START C=1, class_weight=balanced, gamma=auto, kernel=linear.....
# [CV 5/5; 10/18] END C=1, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.957) total time=  41.4s
# [CV 1/5; 11/18] START C=1, class_weight=balanced, gamma=auto, kernel=rbf........
# [CV 1/5; 11/18] END C=1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.992, test=0.990) total time=  12.1s
# [CV 2/5; 11/18] START C=1, class_weight=balanced, gamma=auto, kernel=rbf........
# [CV 2/5; 11/18] END C=1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.991, test=0.991) total time=  12.5s
# [CV 3/5; 11/18] START C=1, class_weight=balanced, gamma=auto, kernel=rbf........
# [CV 3/5; 11/18] END C=1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.992, test=0.991) total time=  12.6s
# [CV 4/5; 11/18] START C=1, class_weight=balanced, gamma=auto, kernel=rbf........
# [CV 4/5; 11/18] END C=1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.992, test=0.992) total time=  12.5s
# [CV 5/5; 11/18] START C=1, class_weight=balanced, gamma=auto, kernel=rbf........
# [CV 5/5; 11/18] END C=1, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.992, test=0.991) total time=  12.6s
# [CV 1/5; 12/18] START C=1, class_weight=balanced, gamma=auto, kernel=poly.......
# [CV 1/5; 12/18] END C=1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.987, test=0.985) total time=  12.1s
# [CV 2/5; 12/18] START C=1, class_weight=balanced, gamma=auto, kernel=poly.......
# [CV 2/5; 12/18] END C=1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.987, test=0.986) total time=  12.3s
# [CV 3/5; 12/18] START C=1, class_weight=balanced, gamma=auto, kernel=poly.......
# [CV 3/5; 12/18] END C=1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.987, test=0.986) total time=  12.4s
# [CV 4/5; 12/18] START C=1, class_weight=balanced, gamma=auto, kernel=poly.......
# [CV 4/5; 12/18] END C=1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.988, test=0.988) total time=  12.0s
# [CV 5/5; 12/18] START C=1, class_weight=balanced, gamma=auto, kernel=poly.......
# [CV 5/5; 12/18] END C=1, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.987, test=0.985) total time=  12.0s
# [CV 1/5; 13/18] START C=10, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 1/5; 13/18] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.960, test=0.958) total time= 3.4min
# [CV 2/5; 13/18] START C=10, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 2/5; 13/18] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.964, test=0.964) total time= 3.7min
# [CV 3/5; 13/18] START C=10, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 3/5; 13/18] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.960, test=0.961) total time= 3.7min
# [CV 4/5; 13/18] START C=10, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 4/5; 13/18] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.964, test=0.964) total time= 4.4min
# [CV 5/5; 13/18] START C=10, class_weight=balanced, gamma=scale, kernel=linear...
# [CV 5/5; 13/18] END C=10, class_weight=balanced, gamma=scale, kernel=linear;, score=(train=0.959, test=0.957) total time= 3.4min
# [CV 1/5; 14/18] START C=10, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 1/5; 14/18] END C=10, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.996, test=0.994) total time=   9.6s
# [CV 2/5; 14/18] START C=10, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 2/5; 14/18] END C=10, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.996, test=0.995) total time=   9.1s
# [CV 3/5; 14/18] START C=10, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 3/5; 14/18] END C=10, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.996, test=0.995) total time=   9.8s
# [CV 4/5; 14/18] START C=10, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 4/5; 14/18] END C=10, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.996, test=0.995) total time=   9.8s
# [CV 5/5; 14/18] START C=10, class_weight=balanced, gamma=scale, kernel=rbf......
# [CV 5/5; 14/18] END C=10, class_weight=balanced, gamma=scale, kernel=rbf;, score=(train=0.996, test=0.995) total time=  10.1s
# [CV 1/5; 15/18] START C=10, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 1/5; 15/18] END C=10, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.996, test=0.993) total time=   7.1s
# [CV 2/5; 15/18] START C=10, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 2/5; 15/18] END C=10, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.996, test=0.994) total time=   7.7s
# [CV 3/5; 15/18] START C=10, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 3/5; 15/18] END C=10, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.995, test=0.994) total time=   7.1s
# [CV 4/5; 15/18] START C=10, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 4/5; 15/18] END C=10, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.995, test=0.994) total time=   6.9s
# [CV 5/5; 15/18] START C=10, class_weight=balanced, gamma=scale, kernel=poly.....
# [CV 5/5; 15/18] END C=10, class_weight=balanced, gamma=scale, kernel=poly;, score=(train=0.996, test=0.994) total time=   8.8s
# [CV 1/5; 16/18] START C=10, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 1/5; 16/18] END C=10, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.960, test=0.958) total time= 3.6min
# [CV 2/5; 16/18] START C=10, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 2/5; 16/18] END C=10, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.964, test=0.964) total time= 3.9min
# [CV 3/5; 16/18] START C=10, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 3/5; 16/18] END C=10, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.960, test=0.961) total time= 3.4min
# [CV 4/5; 16/18] START C=10, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 4/5; 16/18] END C=10, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.964, test=0.964) total time= 4.1min
# [CV 5/5; 16/18] START C=10, class_weight=balanced, gamma=auto, kernel=linear....
# [CV 5/5; 16/18] END C=10, class_weight=balanced, gamma=auto, kernel=linear;, score=(train=0.959, test=0.957) total time= 3.6min
# [CV 1/5; 17/18] START C=10, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 1/5; 17/18] END C=10, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.996, test=0.994) total time=   8.7s
# [CV 2/5; 17/18] START C=10, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 2/5; 17/18] END C=10, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.996, test=0.995) total time=   8.9s
# [CV 3/5; 17/18] START C=10, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 3/5; 17/18] END C=10, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.996, test=0.995) total time=   9.3s
# [CV 4/5; 17/18] START C=10, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 4/5; 17/18] END C=10, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.996, test=0.995) total time=   8.8s
# [CV 5/5; 17/18] START C=10, class_weight=balanced, gamma=auto, kernel=rbf.......
# [CV 5/5; 17/18] END C=10, class_weight=balanced, gamma=auto, kernel=rbf;, score=(train=0.996, test=0.995) total time=   9.7s
# [CV 1/5; 18/18] START C=10, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 1/5; 18/18] END C=10, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.996, test=0.993) total time=   8.5s
# [CV 2/5; 18/18] START C=10, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 2/5; 18/18] END C=10, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.995, test=0.994) total time=   9.5s
# [CV 3/5; 18/18] START C=10, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 3/5; 18/18] END C=10, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.995, test=0.994) total time=   8.5s
# [CV 4/5; 18/18] START C=10, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 4/5; 18/18] END C=10, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.995, test=0.994) total time=   9.3s
# [CV 5/5; 18/18] START C=10, class_weight=balanced, gamma=auto, kernel=poly......
# [CV 5/5; 18/18] END C=10, class_weight=balanced, gamma=auto, kernel=poly;, score=(train=0.995, test=0.994) total time=   8.6s
# Best Parameters: {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf'}
#
# 0.959 (+/-0.003) for {'C': 0.1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'linear'}
# 0.986 (+/-0.001) for {'C': 0.1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf'}
# 0.975 (+/-0.003) for {'C': 0.1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'poly'}
# 0.959 (+/-0.003) for {'C': 0.1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'linear'}
# 0.986 (+/-0.002) for {'C': 0.1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'}
# 0.975 (+/-0.003) for {'C': 0.1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'poly'}
# 0.96 (+/-0.005) for {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'linear'}
# 0.991 (+/-0.001) for {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf'}
# 0.987 (+/-0.003) for {'C': 1, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'poly'}
# 0.96 (+/-0.005) for {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'linear'}
# 0.991 (+/-0.001) for {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'}
# 0.986 (+/-0.002) for {'C': 1, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'poly'}
# 0.961 (+/-0.006) for {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'linear'}
# 0.995 (+/-0.001) for {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'rbf'}
# 0.994 (+/-0.001) for {'C': 10, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'poly'}
# 0.961 (+/-0.006) for {'C': 10, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'linear'}
# 0.995 (+/-0.001) for {'C': 10, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'rbf'}
# 0.994 (+/-0.001) for {'C': 10, 'class_weight': 'balanced', 'gamma': 'auto', 'kernel': 'poly'}

# %%
grid_search.best_estimator_
# Out:
# SVC(C=10, class_weight='balanced')

# %% [markdown]
# # Save the model

# %%
joblib.dump(grid_search.best_estimator_, 'SVM_model.pkl')
# Out:
# ['SVM_model.pkl']
